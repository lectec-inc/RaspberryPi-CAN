# %% [markdown]
# # 🏆 Module 5: CAN Capstone Project
#
# This is your first capstone project. You will use all the skills you've learned in Modules 1-4 to design and build your own custom system. You will be graded based on the rubric below. Be creative, and make sure your code is clean and well-documented.

# %% [markdown]
# ## Section 1: Your Mission
#
# Your mission is to design and implement a project using CAN bus communication with the VESC motor controller. This demonstrates mastery of telemetry reading, data interpretation, and safe motor control.

# %% [markdown]
# ## Section 2: Project Options
#
# Choose one of the following projects, or design your own (with instructor approval).

# %% [markdown]
# ### Option A: Battery Health Monitor
# **Goal:** Create a smart battery gauge that provides more than just voltage.
# **Requirements:**
# 1. Continuously monitor `Input Voltage`, `Input Current`, and `Amp Hours Consumed`.
# 2. Create a dashboard that displays these values.
# 3. Calculate and display an estimated 'Percentage Remaining' based on a total capacity of 5.0 Amp-hours.
# 4. If the voltage drops below 36V, trigger a continuous beeping alert.

# %% [markdown]
# ### Option B: Performance Analyzer
# **Goal:** Log vehicle performance during a short test run and calculate key metrics.
# **Requirements:**
# 1. Create a script that logs `RPM`, `Motor Current`, and `Input Voltage` to lists for 15 seconds.
# 2. After the logging period, stop the motor.
# 3. Calculate and print the following metrics:
#    - Peak RPM
#    - Peak Motor Current
#    - Average RPM
# 4. Use `matplotlib` to plot RPM over time.

# %% [markdown]
# ### Option C: Temperature Safety System
# **Goal:** Build a system that actively prevents overheating with bounded brake intervention.
# **Requirements:**
# 1. Continuously monitor `FET Temperature`, `RPM`, and `Input Voltage`.
# 2. If temperature exceeds a warning threshold (for example 45C), print a warning state.
# 3. If temperature exceeds a critical threshold (for example 60C), trigger a bounded brake sequence such as `set_brake_current(4.0, 4.0)`.
# 4. Include cooldown logic so interventions are not spammed.
# 5. Keep all intervention values within brake safety bounds.

# %% [markdown]
# ## Section 3: Project Requirements & Rubric

# %% [markdown]
# ### Evaluation Rubric
# | Criteria                   | Points | Description                                         |
# |----------------------------|--------|-----------------------------------------------------|
# | Functionality              | 30     | Project works as intended without errors.           |
# | Code Quality               | 20     | Clean code with comments, proper variable names.    |
# | Error Handling             | 15     | Handles edge cases (`None`, disconnects, bad data). |
# | Safety Logic               | 15     | Uses bounded brake values, cooldown, and guards.    |
# | Documentation              | 20     | Clear explanation of how the project works.         |

# %% [markdown]
# ## Section 4: Project Workspace
# This is your space to build. Use the cells below to document, code, and test your project.

# %%
# 4.1 - System Initialization
# You will need to import all necessary libraries here

# %% [markdown]
# ### 4.2 - Project Documentation
# Use this markdown cell to describe which project you chose and your plan for implementing it.

# %% [markdown]
# // **Project Choice:**
# // **Implementation Plan:**

# %%
# 4.3 - Your Project Code

try:
    # Your main project logic goes here
    pass

except KeyboardInterrupt:
    print("\nProject stopped.")
finally:
    # Always include a cleanup section to safely stop the motor and APIs
    pass
