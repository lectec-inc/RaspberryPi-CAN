# %% [markdown]
# # 🏆 Module 10: AI Capstone Project
#
# This is your second capstone project. You will integrate everything from Modules 1-9 to create a complete system that uses both CAN bus telemetry and AI vision to perform a meaningful task.

# %% [markdown]
# ## Section 1: Your Mission
#
# Your mission is to design and implement a project that **meaningfully combines** AI detection with motor data. Your system must make a decision or perform an action based on input from **both** sensors.

# %% [markdown]
# ## Section 2: Project Options
#
# Choose one of the following projects, or design your own (with instructor approval).

# %% [markdown]
# ### Option A: Autonomous Safety Assistant
# **Goal:** Build a system that not only warns but also *acts*.
# **Implementation:**
# 1. Implement the 'Smart Safety Monitor' from Module 9.
# 2. Add a 'Critical' level where if a person is detected and the RPM is very high, the system automatically sends a `set_brake_current()` command to slow the vehicle down.
# 3. **CRITICAL SAFETY:** This must only activate the brake for a short duration (e.g., 0.5 seconds) and must be tested with extreme care on the test bench.

# %% [markdown]
# ### Option B: Smart Parking Helper
# **Goal:** Create an audible parking assistant that beeps faster as you get closer to an object.
# **Implementation:**
# 1. Use the AI camera to detect a target object (e.g., 'chair' or 'potted plant').
# 2. Use the bounding box height to estimate distance (like in Module 12).
# 3. Create a beep pattern where the delay (`off_time`) between beeps gets shorter as the estimated distance decreases.
# 4. The system should only be active when the vehicle is moving very slowly in reverse (e.g., RPM between -500 and 0).

# %% [markdown]
# ### Option C: Traffic Monitor
# **Goal:** Log environmental data and correlate it with vehicle performance.
# **Implementation:**
# 1. Create a loop that runs for 60 seconds.
# 2. In the loop, count the number of 'person' and 'car' detections.
# 3. At the same time, log the vehicle's `RPM` and `Watt Hours Consumed`.
# 4. At the end of the loop, print a summary report:
#    - Total Persons Detected
#    - Total Cars Detected
#    - Average Speed (RPM)
#    - Total Energy Consumed (Wh)

# %% [markdown]
# ## Section 3: Project Requirements & Rubric

# %% [markdown]
# ### Evaluation Rubric
# | Criteria                   | Points | Description                                         |
# |----------------------------|--------|-----------------------------------------------------|
# | Integration Quality        | 30     | AI and CAN systems work together meaningfully.      |
# | Functionality              | 25     | Project works as intended.                          |
# | Code Quality               | 15     | Clean code, good structure.                         |
# | Error Handling             | 15     | Handles disconnections, edge cases.               |
# | Documentation              | 15     | Clear explanation, diagram.                         |

# %% [markdown]
# ## Section 4: Project Workspace
# This is your space to build. Start with the full system initialization code and build your custom logic from there.

# %%
# 4.1 - Full System Initialization
# You will need to import and initialize both VESCStudentAPI and AIStudentAPI here

# %% [markdown]
# ### 4.2 - Project Documentation
# Use this markdown cell to describe your project, its goal, and a flowchart of your algorithm.

# %% [markdown]
# // **Project Title:**
# // **Problem Statement:**
# // **Solution Overview:**
# // **Flowchart:**

# %%
# 4.3 - Your Project Code

try:
    # Your main project loop goes here
    pass

except KeyboardInterrupt:
    print("\nProject stopped.")
finally:
    # Always include a cleanup section to safely stop all hardware and APIs
    pass
